# %% [markdown]
# <h1><b> 🟢 RUN ALL THE CELLS  <b></h1>

# %%
import joblib, pickle,pandas as pd, numpy as np,warnings
warnings.filterwarnings("ignore")

# %%
# !pip install gdown;

# %%
# Scaler file
# !gdown --id 1kVZ2GNY_FwXV_FVCM2sIvg8n9Ako-4Ed -O svm_scaler.pkl

# SVC model file
# !gdown --id 1WBaLXoWzWfaj6aSoMZojklx03fEP0fwy -O svc_pickle_model.pkl

# Form code file
# !gdown --id 1I4N44dSUZiwbwpmGoVV9NlAU7G5NKi5N -O form.pkl
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1kVZ2GNY_FwXV_FVCM2sIvg8n9Ako-4Ed
# To: /content/svm_scaler.pkl
# 100% 1.31k/1.31k [00:00<00:00, 6.18MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1WBaLXoWzWfaj6aSoMZojklx03fEP0fwy
# To: /content/svc_pickle_model.pkl
# 100% 90.8k/90.8k [00:00<00:00, 101MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# ...

# %%
person_scaler = joblib.load('svm_scaler.pkl')
svc_pickle_model = joblib.load('svc_pickle_model.pkl')
Form = joblib.load('form.pkl')

# %%
exec(Form)
# Out:
# Enter the total area (290-360): 300
# Enter the number of rooms (5-9): 7
# Enter the number of bedrooms (2-8): 3
# Enter the number of bedrooms with washrooms (1-7): 4
# Enter the number of washrooms (3-8): 3
# Enter the roof area (0-120): 4
# Enter the lawn area (70-110): 90
# Enter the number of floors (1-8): 7
# Enter the API (59-99): 77
# Enter the ANB (1-6): 4
# Enter the expected value (0-2041): 3
# The predicted class is: ['D:- 3']

# %% [markdown]
# <h1><b> Thank You ! <b></h1>
